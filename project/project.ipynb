# %%
import numpy as np
import pandas as pd
import nltk #used for nlp
import seaborn as sns
import matplotlib.pyplot as plt
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\adity\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
df=pd.read_csv('as.csv')
a=df.head()
a
# Out:
#                                  RecipeId  \
# 0    d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# 1    d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# 2    d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# 3    d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# 4    d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# ..                                    ...
# 495  85c10e11-4e5a-4823-a3f7-7273ffc8dbad
# 496  85c10e11-4e5a-4823-a3f7-7273ffc8dbad
# 497  85c10e11-4e5a-4823-a3f7-7273ffc8dbad
# 498  85c10e11-4e5a-4823-a3f7-7273ffc8dbad
# 499  85c10e11-4e5a-4823-a3f7-7273ffc8dbad
#
#                                             ReviewText SubmittedTime
# 0    My family  it they want me to make it again so...     4/28/2022
# 1    Was disappointed.  Not as "crispy" as I though...      3/4/2022
# 2    I am in Canada and have never seen  a ranch dr...      3/1/2022
# 3    Everybody loves this dish. So simple to make.d...    11/28/2021
# 4    My family loved this chicken recipe...quick an...    11/20/2021
# ...

# %%
b=df['ReviewText'][50]
print(b)

nltk.word_tokenize(b)
# Out:
# Awesome cookies have made several times and love them!
# ['Awesome',
#  'cookies',
#  'have',
#  'made',
#  'several',
#  'times',
#  'and',
#  'love',
#  'them',
#  '!']

# %%
import numpy as np
import pandas as pd
import nltk
# nltk.download('punkt')
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
# nltk.download('vader_lexicon')

df=pd.read_csv('as.csv')

c=SentimentIntensityAnalyzer()

# df['Star']
n=0

for i in df['ReviewText']:
    s=0
    b=df['ReviewText'][n]


    z=c.polarity_scores(b)
    if(z['compound']>0.8):
        print(5)
        s=5
    elif(z['compound']>0.5 and z['compound']<0.8):
        print(4)
        s=4
    elif(z['compound']>0 and z['compound']<0.5):
        print(3)
        s=3
    elif(z['compound']> -0.5 and z['compound']<0):
        print(2)
        s=2
    elif(z['compound']<-0.7):
        print(1)
        s=1
    n+=1    
    # df.insert(3,value=s)
# Out:
# 3
# 2
# 4
# 4
# 4
# 5
# 4
# 3
# 3
# 4
# 5
# 5
# 4
# 5
# 5
# 4
# 2
# 3
# 5
# 5
# 5
# 5
# 4
# 5
# 4
# 5
# 5
# 5
# 5
# 3
# 4
# 5
# 4
# 5
# 5
# 5
# 1
# 5
# 4
# 5
# 4
# 4
# 4
# 5
# 3
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 4
# 5
# 4
# 5
# 5
# 5
# 4
# 5
# 4
# 4
# 5
# 5
# 5
# 5
# 5
# 5
# 2
# 5
# 5
# 3
# 4
# 5
# 5
# 4
# 4
# 5
# 5
# 4
# 3
# 4
# 5
# 4
# 3
# 5
# 4
# 4
# 2
# 5
# 5
# 4
# 4
# 5
# 3
# 5
# 4
# 4
# 1
# 4
# 3
# 5
# 3
# 4
# 5
# 5
# 4
# 5
# 5
# 5
# 4
# 2
# 5
# 4
# 5
# 4
# 5
# 4
# 5
# 4
# 5
# 4
# 3
# 3
# 3
# 5
# 3
# 5
# 4
# 5
# 5
# 2
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# 5
# 1
# 4
# 4
# 4
# 4
# 4
# 5
# 5
# 5
# 4
# 2
# 4
# 3
# 5
# 4
# 3
# 5
# 4
# 3
# 5
# 3
# 5
# 4
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 3
# 4
# 5
# 4
# 5
# 4
# 5
# 4
# 5
# 3
# 5
# 4
# 4
# 5
# 4
# 5
# 4
# 5
# 5
# 2
# 5
# 4
# 4
# 3
# 5
# 3
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# 4
# 4
# 4
# 2
# 4
# 3
# 4
# 5
# 2
# 2
# 5
# 4
# 5
# 5
# 3
# 4
# 5
# 4
# 4
# 3
# 5
# 5
# 5
# 4
# 5
# 4
# 5
# 3
# 1
# ...

# %%
df
# Out:
#                                      RecipeId  \
# 0        d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# 1        d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# 2        d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# 3        d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# 4        d8ab10cd-6bdd-49f7-a169-adafc91a42bc
# ...                                       ...
# 21857  3cedf120-1b21-426c-ae1e-6171ff84ddfc-z
# 21858  3cedf120-1b21-426c-ae1e-6171ff84ddfc-z
# 21859  3cedf120-1b21-426c-ae1e-6171ff84ddfc-z
# 21860  3cedf120-1b21-426c-ae1e-6171ff84ddfc-z
# 21861  3cedf120-1b21-426c-ae1e-6171ff84ddfc-z
#
#                                               ReviewText SubmittedTime  Star  \
# 0      My family  it they want me to make it again so...     4/28/2022     5
# 1      Was disappointed.  Not as "crispy" as I though...      3/4/2022     5
# 2      I am in Canada and have never seen  a ranch dr...      3/1/2022     5
# 3      Everybody loves this dish. So simple to make.d...    11/28/2021     5
# ...
